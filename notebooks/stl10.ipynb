# %%
# !nvidia-smi
# Out:
# Wed Nov 19 05:40:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             25W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Import libraries

# %%
# !git clone https://github.com/VuTrinhNguyenHoang/eX-LAViTs.git
# Out:
# Cloning into 'eX-LAViTs'...
# remote: Enumerating objects: 432, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 432 (delta 47), reused 53 (delta 24), pack-reused 351 (from 1)
# Receiving objects: 100% (432/432), 171.19 KiB | 5.90 MiB/s, done.
# Resolving deltas: 100% (275/275), done.

# %%
# %cd eX-LAViTs
# !ls -l
# Out:
# /kaggle/working/eX-LAViTs
# total 28
# drwxr-xr-x 2 root root 4096 Nov 19 05:40 configs
# drwxr-xr-x 2 root root 4096 Nov 19 05:40 datasets
# drwxr-xr-x 2 root root 4096 Nov 19 05:40 notebooks
# -rw-r--r-- 1 root root  315 Nov 19 05:40 README.md
# -rw-r--r-- 1 root root   93 Nov 19 05:40 requirements.txt
# drwxr-xr-x 4 root root 4096 Nov 19 05:40 src
# drwxr-xr-x 2 root root 4096 Nov 19 05:40 tests

# %%
# Repository
from src.models.linear_vit import create_linear_attention_vit
from src.models.explainability import ViTGradCAM, IntegratedGradient, Rollout, LAGRA
from src.utils.training import (
    create_run_directory, setup_logging, get_optimizer, get_scheduler,
    train_model, count_parameters, load_checkpoint
)
from src.pretrained import freeze_all_except_last_k_blocks, unfreeze_all
from src.utils.metrics import compute_loss_and_accuracy, compute_classification_metrics, evaluate_xai_method_dataset, evaluate_class_specificity_cosine
from src.utils.visualization import save_all_plots, create_training_summary_plot
from src.explain import visualize_methods
from datasets import get_stl10_dataloaders

# Pytorch
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as T
from torchvision.transforms.autoaugment import AutoAugment, AutoAugmentPolicy
import timm
from sklearn.model_selection import train_test_split

from pathlib import Path
from PIL import Image
import pandas as pd
import numpy as np
import math
from tqdm.auto import tqdm
import os

# %% [markdown]
# ## Config

# %%
run_name = "run001"

LR = 1e-4
WD = 1e-4

EPOCHS = 100
warmup_epochs = 10
remaining_epochs = EPOCHS - warmup_epochs

PATIENCE = 5

BATCH_SIZE = 64
NUM_WORKERS = 4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

IMAGE_SIZE = 224

SEED = 42
np.random.seed(SEED); torch.manual_seed(SEED)
print(NUM_WORKERS, DEVICE)
# Out:
# 4 cuda

# %% [markdown]
# ## Datasets

# %%
train_loader, valid_loader, test_loader = get_stl10_dataloaders(batch_size=BATCH_SIZE)

len(train_loader), len(valid_loader), len(test_loader)
# Out:
# 100%|██████████| 2.64G/2.64G [03:10<00:00, 13.9MB/s]
# (70, 8, 125)

# %%
batch_test = next(iter(train_loader))
batch_test[0].shape, batch_test[1].shape
# Out:
# (torch.Size([64, 3, 96, 96]), torch.Size([64]))

# %% [markdown]
# ## Train model

# %%
model_name = "vit_tiny_patch16_224"

model = create_linear_attention_vit(
    model_name,
    pretrained=True,
    num_classes=10,
    img_size=96,
    drop_path_rate=0.1,
    attn_drop_rate=0.1,
    proj_drop_rate=0.1,
)
# Out:
# Creating Linear Attention ViT: vit_tiny_patch16_224
#     Pretrained: True
#     Classes: 10
#     Image size: 96
# model.safetensors:   0%|          | 0.00/22.9M [00:00<?, ?B/s]
#     Original parameters: 5,495,626
# Replacing attention layers with LinearMultiheadAttention...
#     Kernel: elu
#     Epsilon: 1e-06
#    Block 0: dim=192, heads=3, mlp_ratio=4.0
#    Block 1: dim=192, heads=3, mlp_ratio=4.0
#    Block 2: dim=192, heads=3, mlp_ratio=4.0
#    Block 3: dim=192, heads=3, mlp_ratio=4.0
#    Block 4: dim=192, heads=3, mlp_ratio=4.0
#    Block 5: dim=192, heads=3, mlp_ratio=4.0
#    Block 6: dim=192, heads=3, mlp_ratio=4.0
#    Block 7: dim=192, heads=3, mlp_ratio=4.0
#    Block 8: dim=192, heads=3, mlp_ratio=4.0
#    Block 9: dim=192, heads=3, mlp_ratio=4.0
#    Block 10: dim=192, heads=3, mlp_ratio=4.0
#    Block 11: dim=192, heads=3, mlp_ratio=4.0
# Successfully replaced 12 attention blocks
#     Total parameters: 5,495,626
#     Trainable parameters: 5,495,626

# %%
run_dir = create_run_directory("experiments", run_name)
print(f"Created run directory: {run_dir}")

logger = setup_logging(os.path.join(run_dir, 'logs'))
logger.info(f"Starting training with {run_name}")
logger.info(f"Using device: {DEVICE}")

logger.info(f"Train batches: {len(train_loader)}")
logger.info(f"Validation batches: {len(valid_loader)}")
logger.info(f"Test batches: {len(test_loader)}")

model = model.to(DEVICE)
total_params, trainable_params = count_parameters(model)
logger.info(f"Model loaded with {total_params:,} total parameters ({trainable_params:,} trainable)")

criterion = nn.CrossEntropyLoss()
logger.info("Starting training...")
# Out:
# 2025-11-19 05:44:44 - training - INFO - Starting training with run001
# 2025-11-19 05:44:44 - training - INFO - Using device: cuda
# 2025-11-19 05:44:44 - training - INFO - Train batches: 70
# 2025-11-19 05:44:44 - training - INFO - Validation batches: 8
# 2025-11-19 05:44:44 - training - INFO - Test batches: 125
# 2025-11-19 05:44:44 - training - INFO - Model loaded with 5,495,626 total parameters (5,495,626 trainable)
# 2025-11-19 05:44:44 - training - INFO - Starting training...
# Created run directory: experiments/run001

# %%
if warmup_epochs > 0:
    logger.info(f"Phase 1: Warm-up last 4 blocks for {warmup_epochs} epochs")
    freeze_all_except_last_k_blocks(model, k=4, logger=logger)
    optimizer1 = get_optimizer(
        model,
        optimizer_name="adamw",
        learning_rate=LR * 0.5,
        weight_decay=WD,
    )
    scheduler1 = get_scheduler(
        optimizer1, 
        "cosine", 
        **{
            "T_max": warmup_epochs,
            "eta_min": 0
        }
    )

    metrics_phase1 = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=valid_loader,
        criterion=criterion,
        optimizer=optimizer1,
        scheduler=scheduler1,
        device=DEVICE,
        num_epochs=warmup_epochs,
        run_dir=run_dir,
        save_freq=50,
        print_freq=50,
        early_stopping_patience=PATIENCE,
        logger=logger
    )
    logger.info("Phase 1 completed.")
# Out:
# 2025-11-19 05:44:44 - training - INFO - Phase 1: Warm-up last 4 blocks for 10 epochs
# 2025-11-19 05:44:44 - training - INFO - [Warmup] Trainable params with last 4 blocks: 2,967,562
# 2025-11-19 05:44:44 - training - INFO - Starting epoch 1/10
# 2025-11-19 05:45:25 - training - INFO - Epoch 8 completed. Train Loss: 1.5468, Val Loss: 1.5165, Val Acc: 42.40%, Epoch Time: 4.92s, Memory: 1842MB
# 2025-11-19 05:45:25 - training - INFO - Starting epoch 9/10
# 2025-11-19 05:45:25 - training - INFO - Epoch: [9][0/70]	Time 0.432 (0.432)	Loss 1.5814 (1.5814)	Acc@1 46.875 (46.875)	Memory 1842MB
# 2025-11-19 05:45:28 - training - INFO - Epoch: [9][50/70]	Time 0.078 (0.070)	Loss 1.5798 (1.5348)	Acc@1 35.938 (41.023)	Memory 1842MB
# 2025-11-19 05:45:29 - training - INFO - Validation: [9]	Time 0.039 (Total: 0.34s)	Loss 1.5118	Acc@1 43.600	Memory 1842MB
# 2025-11-19 05:45:29 - training - INFO - New best model saved with validation accuracy: 43.600
# 2025-11-19 05:45:29 - training - INFO - Epoch 9 completed. Train Loss: 1.5462, Val Loss: 1.5118, Val Acc: 43.60%, Epoch Time: 4.86s, Memory: 1842MB
# 2025-11-19 05:45:29 - training - INFO - Starting epoch 10/10
# 2025-11-19 05:45:30 - training - INFO - Epoch: [10][0/70]	Time 0.445 (0.445)	Loss 1.6296 (1.6296)	Acc@1 35.938 (35.938)	Memory 1843MB
# 2025-11-19 05:45:33 - training - INFO - Epoch: [10][50/70]	Time 0.066 (0.070)	Loss 1.7674 (1.5570)	Acc@1 37.500 (40.962)	Memory 1843MB
# 2025-11-19 05:45:34 - training - INFO - Validation: [10]	Time 0.039 (Total: 0.35s)	Loss 1.5110	Acc@1 43.400	Memory 1843MB
# 2025-11-19 05:45:35 - training - INFO - Epoch 10 completed. Train Loss: 1.5460, Val Loss: 1.5110, Val Acc: 43.40%, Epoch Time: 4.95s, Memory: 1843MB
# 2025-11-19 05:45:35 - training - INFO - Phase 1 completed.

# %%
if remaining_epochs > 0:
    logger.info(f"Phase 2: Unfreeze last 8 blocks and finetune for {remaining_epochs} epochs")
    freeze_all_except_last_k_blocks(model, k=8, logger=logger)
    optimizer2 = get_optimizer(
        model,
        optimizer_name="adamw",
        learning_rate=LR,
        weight_decay=WD,
    )
    scheduler2 = get_scheduler(
        optimizer2, 
        "cosine", 
        **{
            "T_max": remaining_epochs,
            "eta_min": 0
        }
    )

    metrics_phase2 = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=valid_loader,
        criterion=criterion,
        optimizer=optimizer2,
        scheduler=scheduler2,
        device=DEVICE,
        num_epochs=remaining_epochs,
        run_dir=run_dir,
        save_freq=50,
        print_freq=50,
        early_stopping_patience=PATIENCE,
        logger=logger
    )
    logger.info("Phase 2 completed.")
# Out:
# 2025-11-19 05:45:35 - training - INFO - Phase 2: Unfreeze last 8 blocks and finetune for 90 epochs
# 2025-11-19 05:45:35 - training - INFO - [Warmup] Trainable params with last 8 blocks: 4,154,122
# 2025-11-19 05:45:35 - training - INFO - Starting epoch 1/90
# 2025-11-19 05:45:35 - training - INFO - Epoch: [1][0/70]	Time 0.410 (0.410)	Loss 1.4609 (1.4609)	Acc@1 45.312 (45.312)	Memory 1843MB
# 2025-11-19 05:45:38 - training - INFO - Epoch: [1][50/70]	Time 0.049 (0.069)	Loss 1.4378 (1.5888)	Acc@1 50.000 (37.684)	Memory 1843MB
# 2025-11-19 05:46:00 - training - INFO - Validation: [5]	Time 0.039 (Total: 0.35s)	Loss 1.3635	Acc@1 48.200	Memory 1843MB
# 2025-11-19 05:46:00 - training - INFO - Epoch 5 completed. Train Loss: 1.3756, Val Loss: 1.3635, Val Acc: 48.20%, Epoch Time: 4.87s, Memory: 1843MB
# 2025-11-19 05:46:00 - training - INFO - Starting epoch 6/90
# 2025-11-19 05:46:00 - training - INFO - Epoch: [6][0/70]	Time 0.450 (0.450)	Loss 1.1937 (1.1937)	Acc@1 62.500 (62.500)	Memory 1843MB
# 2025-11-19 05:46:03 - training - INFO - Epoch: [6][50/70]	Time 0.066 (0.070)	Loss 1.0286 (1.3429)	Acc@1 65.625 (49.234)	Memory 1844MB
# 2025-11-19 05:46:05 - training - INFO - Validation: [6]	Time 0.039 (Total: 0.34s)	Loss 1.3912	Acc@1 48.200	Memory 1843MB
# 2025-11-19 05:46:05 - training - INFO - Epoch 6 completed. Train Loss: 1.3439, Val Loss: 1.3912, Val Acc: 48.20%, Epoch Time: 4.91s, Memory: 1843MB
# 2025-11-19 05:46:05 - training - INFO - Starting epoch 7/90
# 2025-11-19 05:46:05 - training - INFO - Epoch: [7][0/70]	Time 0.425 (0.425)	Loss 1.3530 (1.3530)	Acc@1 54.688 (54.688)	Memory 1843MB
# 2025-11-19 05:46:08 - training - INFO - Epoch: [7][50/70]	Time 0.048 (0.069)	Loss 1.5013 (1.3323)	Acc@1 37.500 (48.468)	Memory 1843MB
# 2025-11-19 05:46:09 - training - INFO - Validation: [7]	Time 0.039 (Total: 0.35s)	Loss 1.3809	Acc@1 49.400	Memory 1843MB
# 2025-11-19 05:46:09 - training - INFO - Early stopping triggered after 5 epochs without improvement
# 2025-11-19 05:46:09 - training - INFO - Phase 2 completed.

# %% [markdown]
# ## Evaluate

# %%
logger.info("Training completed!")

# Evaluate on test setlogger.info("Evaluating on test set...")
test_results = compute_loss_and_accuracy(
    model, test_loader, criterion, DEVICE, return_predictions=True
)

# Compute detailed classification metrics
classification_metrics = compute_classification_metrics(
    test_results['predictions'],
    test_results['targets'],
    return_confusion_matrix=True
)

# Log test results
logger.info(f"Test Results:")
logger.info(f"  Loss: {test_results['loss']:.4f}")
logger.info(f"  Top-1 Accuracy: {test_results['top1_accuracy']:.2f}%")
logger.info(f"  Macro F1-Score: {classification_metrics['macro_f1']:.2f}%")
logger.info(f"  Weighted F1-Score: {classification_metrics['weighted_f1']:.2f}%")
# Out:
# 2025-11-19 05:46:10 - training - INFO - Training completed!
# 2025-11-19 05:46:13 - training - INFO - Test Results:
# 2025-11-19 05:46:13 - training - INFO -   Loss: 1.4363
# 2025-11-19 05:46:13 - training - INFO -   Top-1 Accuracy: 47.11%
# 2025-11-19 05:46:13 - training - INFO -   Macro F1-Score: 44.86%
# 2025-11-19 05:46:13 - training - INFO -   Weighted F1-Score: 44.86%

# %%
# Generate and save plots
logger.info("Generating plots...")
save_all_plots(
    metrics_tracker=metrics_phase2,
    run_dir=run_dir,
    y_true=test_results['targets'],
    y_pred=test_results['predictions'],
)

# Create comprehensive training summary plot
model_info = {
    'model_name': model_name,
    'total_params': total_params,
}

summary_plot = create_training_summary_plot(metrics_phase2, model_info)
summary_plot.savefig(
    os.path.join(run_dir, 'plots', 'training_summary.png'),
    bbox_inches='tight', dpi=300
)
# Out:
# 2025-11-19 05:46:13 - training - INFO - Generating plots...

# %% [markdown]
# ## Explain

# %%
model.to(DEVICE).eval()
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 192, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (1): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (2): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (3): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (4): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (5): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (6): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (7): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (8): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (9): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (10): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#     (11): LinearAttentionBlock(
#       (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (attn): LinearMultiheadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (out_proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.1, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.1, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=192, out_features=10, bias=True)
# )

# %%
# %matplotlib inline
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')

# %% [markdown]
# ### LAGRA

# %%
test_dataset = test_loader.dataset

idx = np.random.randint(len(test_dataset))

x, y_true = test_dataset[idx] # test sample
xb = x.unsqueeze(0).to(DEVICE)

# %%
proposal_model = LAGRA(model, has_cls=True, blocks_attr="blocks")

out = proposal_model.attribute(xb, use_logits=True)

# %%
out[0].shape, out[1].shape, out[0].mean(), out[1].mean()
# Out:
# (torch.Size([1, 36]),
#  torch.Size([1, 1, 96, 96]),
#  tensor(0.6224, device='cuda:0', grad_fn=<MeanBackward0>),
#  tensor(0.4636, device='cuda:0', grad_fn=<MeanBackward0>))

# %% [markdown]
# ### GradCAM

# %%
gradcam_model = ViTGradCAM(model, has_cls=True)

out = gradcam_model.attribute(xb)

# %%
out[0].shape, out[1].shape, out[0].mean(), out[1].mean()
# Out:
# (torch.Size([1, 36]),
#  torch.Size([1, 1, 96, 96]),
#  tensor(0.8765, device='cuda:0', grad_fn=<MeanBackward0>),
#  tensor(0.6186, device='cuda:0', grad_fn=<MeanBackward0>))

# %% [markdown]
# ### Integrated Gradients

# %%
ig_model = IntegratedGradient(model, m_steps=32)

out = ig_model.attribute(xb)

# %%
out[0].shape, out[1].shape, out[0].mean(), out[1].mean()
# Out:
# (torch.Size([1, 36]),
#  torch.Size([1, 1, 96, 96]),
#  tensor(0.4486, device='cuda:0'),
#  tensor(0.1012, device='cuda:0'))

# %% [markdown]
# ### Rollout

# %%
rollout_model = Rollout(model, has_cls=True)

out = rollout_model.attribute(xb)

# %%
out[0].shape, out[1].shape, out[0].mean(), out[1].mean()
# Out:
# (torch.Size([1, 36]),
#  torch.Size([1, 1, 96, 96]),
#  tensor(0.9094, device='cuda:0'),
#  tensor(0.5475, device='cuda:0'))

# %% [markdown]
# ## Visualization

# %%
idx = np.random.randint(len(test_dataset))
print(idx)

_ = visualize_methods(
    test_dataset, idx,
    {
        "Ours": proposal_model,
        "GradCAM": gradcam_model,
        "IntegratedGradient": ig_model,
        "Rollout": rollout_model
    },
    use_pred=True,
    device=DEVICE,
)
# Out:
# 7603

# %% [markdown]
# ## Evaluate Explain methods

# %%
methods = {
    "Ours": proposal_model,
    "GradCAM": gradcam_model,
    "IG": ig_model,
    "Rollout": rollout_model
}

results = {}
for name, attr in methods.items():
    print(f"Evaluating {name}...")
    stats_faith = evaluate_xai_method_dataset(
        attributor=attr,
        dataset=test_dataset,
        device=DEVICE,
        use_pred=True,
        max_samples=640,
        steps=20,
        baseline=None,
        use_logits=True,
        verbose_every=50,
    )

    stats_cs = evaluate_class_specificity_cosine(
        attributor=attr,
        dataset=test_dataset,
        device=DEVICE,
        max_samples=640,
        use_logits=True,
        use_pred=True,
        verbose_every=50,
    )

    metrics = {
        **stats_faith,
        "cosine_cs_mean": stats_cs["cosine_cs_mean"],
        "cosine_cs_std": stats_cs["cosine_cs_std"],
    }
    results[name] = metrics
    print(f"Results for {name}: {metrics}")
    print("-" * 50)
# Out:
# Evaluating Ours...
# [50/640] AUC_del_mean=0.4371, AUC_ins_mean=0.5411, entropy_mean=0.9643
# [100/640] AUC_del_mean=0.4371, AUC_ins_mean=0.5455, entropy_mean=0.9617
# [150/640] AUC_del_mean=0.4331, AUC_ins_mean=0.5443, entropy_mean=0.9628
# [200/640] AUC_del_mean=0.4184, AUC_ins_mean=0.5336, entropy_mean=0.9621
# [250/640] AUC_del_mean=0.4215, AUC_ins_mean=0.5376, entropy_mean=0.9601
# [300/640] AUC_del_mean=0.4282, AUC_ins_mean=0.5425, entropy_mean=0.9595
# [350/640] AUC_del_mean=0.4248, AUC_ins_mean=0.5395, entropy_mean=0.9593
# [400/640] AUC_del_mean=0.4238, AUC_ins_mean=0.5398, entropy_mean=0.9597
# [450/640] AUC_del_mean=0.4204, AUC_ins_mean=0.5369, entropy_mean=0.9597
# [500/640] AUC_del_mean=0.4220, AUC_ins_mean=0.5381, entropy_mean=0.9599
# [550/640] AUC_del_mean=0.4223, AUC_ins_mean=0.5381, entropy_mean=0.9601
# [600/640] AUC_del_mean=0.4255, AUC_ins_mean=0.5404, entropy_mean=0.9604
# [50/640] cosine_cs_mean=0.0033
# [100/640] cosine_cs_mean=0.0024
# [150/640] cosine_cs_mean=0.0204
# [200/640] cosine_cs_mean=0.0558
# [250/640] cosine_cs_mean=0.0580
# [300/640] cosine_cs_mean=0.0658
# [350/640] cosine_cs_mean=0.0668
# [400/640] cosine_cs_mean=0.0555
# [450/640] cosine_cs_mean=0.0570
# [500/640] cosine_cs_mean=0.0546
# [550/640] cosine_cs_mean=0.0489
# [600/640] cosine_cs_mean=0.0584
# Results for Ours: {'auc_del_mean': 0.4249875677692135, 'auc_ins_mean': 0.5382093709415496, 'entropy_mean': 0.9601898299628997, 'gini_mean': 0.9631394061696483, 'n_samples': 640, 'cosine_cs_mean': 0.05593026625738275, 'cosine_cs_std': 0.46204493890801523}
# --------------------------------------------------
# Evaluating GradCAM...
# [50/640] AUC_del_mean=0.4754, AUC_ins_mean=0.4997, entropy_mean=0.9961
# [100/640] AUC_del_mean=0.4760, AUC_ins_mean=0.5043, entropy_mean=0.9951
# [150/640] AUC_del_mean=0.4719, AUC_ins_mean=0.5025, entropy_mean=0.9951
# [200/640] AUC_del_mean=0.4611, AUC_ins_mean=0.4883, entropy_mean=0.9951
# [250/640] AUC_del_mean=0.4686, AUC_ins_mean=0.4891, entropy_mean=0.9953
# [300/640] AUC_del_mean=0.4743, AUC_ins_mean=0.4950, entropy_mean=0.9949
# [350/640] AUC_del_mean=0.4695, AUC_ins_mean=0.4930, entropy_mean=0.9948
# [400/640] AUC_del_mean=0.4690, AUC_ins_mean=0.4937, entropy_mean=0.9950
# [450/640] AUC_del_mean=0.4654, AUC_ins_mean=0.4916, entropy_mean=0.9945
# [500/640] AUC_del_mean=0.4668, AUC_ins_mean=0.4934, entropy_mean=0.9945
# [550/640] AUC_del_mean=0.4671, AUC_ins_mean=0.4932, entropy_mean=0.9945
# [600/640] AUC_del_mean=0.4697, AUC_ins_mean=0.4962, entropy_mean=0.9945
# [50/640] cosine_cs_mean=0.1596
# [100/640] cosine_cs_mean=0.1972
# [150/640] cosine_cs_mean=0.2099
# [200/640] cosine_cs_mean=0.2217
# [250/640] cosine_cs_mean=0.2202
# [300/640] cosine_cs_mean=0.2192
# [350/640] cosine_cs_mean=0.2320
# [400/640] cosine_cs_mean=0.2278
# [450/640] cosine_cs_mean=0.2243
# [500/640] cosine_cs_mean=0.2223
# [550/640] cosine_cs_mean=0.2239
# [600/640] cosine_cs_mean=0.2233
# Results for GradCAM: {'auc_del_mean': 0.46791706338262246, 'auc_ins_mean': 0.4953322758707584, 'entropy_mean': 0.9945488986837734, 'gini_mean': 0.971241413243115, 'n_samples': 640, 'cosine_cs_mean': 0.22068016937246285, 'cosine_cs_std': 0.40358878694415035}
# --------------------------------------------------
# Evaluating IG...
# [50/640] AUC_del_mean=0.4946, AUC_ins_mean=0.4792, entropy_mean=0.9791
# [100/640] AUC_del_mean=0.5007, AUC_ins_mean=0.4856, entropy_mean=0.9793
# [150/640] AUC_del_mean=0.4976, AUC_ins_mean=0.4810, entropy_mean=0.9787
# [200/640] AUC_del_mean=0.4840, AUC_ins_mean=0.4695, entropy_mean=0.9784
# [250/640] AUC_del_mean=0.4889, AUC_ins_mean=0.4737, entropy_mean=0.9784
# [300/640] AUC_del_mean=0.4935, AUC_ins_mean=0.4803, entropy_mean=0.9786
# [350/640] AUC_del_mean=0.4896, AUC_ins_mean=0.4779, entropy_mean=0.9784
# [400/640] AUC_del_mean=0.4903, AUC_ins_mean=0.4776, entropy_mean=0.9782
# [450/640] AUC_del_mean=0.4877, AUC_ins_mean=0.4749, entropy_mean=0.9779
# [500/640] AUC_del_mean=0.4891, AUC_ins_mean=0.4761, entropy_mean=0.9782
# [550/640] AUC_del_mean=0.4895, AUC_ins_mean=0.4761, entropy_mean=0.9780
# [600/640] AUC_del_mean=0.4923, AUC_ins_mean=0.4793, entropy_mean=0.9779
# [50/640] cosine_cs_mean=0.5968
# [100/640] cosine_cs_mean=0.6193
# [150/640] cosine_cs_mean=0.6225
# [200/640] cosine_cs_mean=0.6207
# [250/640] cosine_cs_mean=0.6227
# [300/640] cosine_cs_mean=0.6270
# [350/640] cosine_cs_mean=0.6276
# [400/640] cosine_cs_mean=0.6292
# [450/640] cosine_cs_mean=0.6318
# [500/640] cosine_cs_mean=0.6286
# [550/640] cosine_cs_mean=0.6273
# [600/640] cosine_cs_mean=0.6265
# Results for IG: {'auc_del_mean': 0.49133705956084733, 'auc_ins_mean': 0.47796768916487675, 'entropy_mean': 0.977797311839581, 'gini_mean': 0.9675130137067753, 'n_samples': 640, 'cosine_cs_mean': 0.62789017977193, 'cosine_cs_std': 0.10873262756073251}
# --------------------------------------------------
# Evaluating Rollout...
# [50/640] AUC_del_mean=0.4574, AUC_ins_mean=0.5175, entropy_mean=0.9989
# [100/640] AUC_del_mean=0.4574, AUC_ins_mean=0.5253, entropy_mean=0.9989
# [150/640] AUC_del_mean=0.4543, AUC_ins_mean=0.5218, entropy_mean=0.9989
# [200/640] AUC_del_mean=0.4404, AUC_ins_mean=0.5077, entropy_mean=0.9989
# [250/640] AUC_del_mean=0.4448, AUC_ins_mean=0.5115, entropy_mean=0.9989
# [300/640] AUC_del_mean=0.4538, AUC_ins_mean=0.5149, entropy_mean=0.9989
# [350/640] AUC_del_mean=0.4502, AUC_ins_mean=0.5110, entropy_mean=0.9989
# [400/640] AUC_del_mean=0.4512, AUC_ins_mean=0.5105, entropy_mean=0.9989
# [450/640] AUC_del_mean=0.4489, AUC_ins_mean=0.5071, entropy_mean=0.9989
# [500/640] AUC_del_mean=0.4502, AUC_ins_mean=0.5089, entropy_mean=0.9989
# [550/640] AUC_del_mean=0.4513, AUC_ins_mean=0.5082, entropy_mean=0.9989
# [600/640] AUC_del_mean=0.4546, AUC_ins_mean=0.5108, entropy_mean=0.9989
# [50/640] cosine_cs_mean=1.0000
# [100/640] cosine_cs_mean=1.0000
# [150/640] cosine_cs_mean=1.0000
# [200/640] cosine_cs_mean=1.0000
# [250/640] cosine_cs_mean=1.0000
# [300/640] cosine_cs_mean=1.0000
# [350/640] cosine_cs_mean=1.0000
# [400/640] cosine_cs_mean=1.0000
# [450/640] cosine_cs_mean=1.0000
# [500/640] cosine_cs_mean=1.0000
# [550/640] cosine_cs_mean=1.0000
# [600/640] cosine_cs_mean=1.0000
# Results for Rollout: {'auc_del_mean': 0.4530384901834365, 'auc_ins_mean': 0.5096055373734217, 'entropy_mean': 0.9988936773668418, 'gini_mean': 0.9720016021892661, 'n_samples': 640, 'cosine_cs_mean': 1.0000000054016709, 'cosine_cs_std': 9.790481777924887e-08}
# --------------------------------------------------

# %%
results
# Out:
# {'Ours': {'auc_del_mean': 0.4249875677692135,
#   'auc_ins_mean': 0.5382093709415496,
#   'entropy_mean': 0.9601898299628997,
#   'gini_mean': 0.9631394061696483,
#   'n_samples': 640,
#   'cosine_cs_mean': 0.05593026625738275,
#   'cosine_cs_std': 0.46204493890801523},
#  'GradCAM': {'auc_del_mean': 0.46791706338262246,
#   'auc_ins_mean': 0.4953322758707584,
#   'entropy_mean': 0.9945488986837734,
#   'gini_mean': 0.971241413243115,
#   'n_samples': 640,
#   'cosine_cs_mean': 0.22068016937246285,
#   'cosine_cs_std': 0.40358878694415035},
#  'IG': {'auc_del_mean': 0.49133705956084733,
#   'auc_ins_mean': 0.47796768916487675,
#   'entropy_mean': 0.977797311839581,
#   'gini_mean': 0.9675130137067753,
#   'n_samples': 640,
#   'cosine_cs_mean': 0.62789017977193,
#   'cosine_cs_std': 0.10873262756073251},
#  'Rollout': {'auc_del_mean': 0.4530384901834365,
#   'auc_ins_mean': 0.5096055373734217,
#   'entropy_mean': 0.9988936773668418,
#   'gini_mean': 0.9720016021892661,
#   'n_samples': 640,
#   'cosine_cs_mean': 1.0000000054016709,
#   'cosine_cs_std': 9.790481777924887e-08}}
